# %%
def menu():
    print("=================================")
    print("         Selamat Datang          ")
    print("      di Restoran Burgeria       ")
    print("=================================")
    print("Silahkan isi data diri anda terlebih dahulu")
    nama = input ("Masukkan nama pembeli : ")
    umur = int(input("Masukkan umur pembeli : "))
    print("\n")
    print("Berikut ini menu restoran yang ada :")
    print("1. Kentang Goreng")
    print("2. Burger Vegetarian")
    print("3. Burger Mayo")
    print("4. Burger Keju")
    print("5. Burger Pedas")
    pilih_menu = int(input("Masukkan menu yang ingin dibeli :"))
    print("\n") #baris 16
    if pilih_menu == 1 :
        print("=====================")
        print("        Porsi        ")
        print("=====================")
        print("1. Kecil Rp30.000")
        print("2. Sedang Rp35.000")
        print("3. Besar Rp40.000")
        pilih_porsi = int(input("Pilih porsi yang diinginkan : "))
        print("\n")
        if pilih_porsi == 1 :
            print("Anda memilih porsi kecil seharga Rp30.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_kecil = 30000*jmlh_porsi
            print("Total harga pesanan anda ",harga_porsi_kecil)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 2 :
            print("Anda memilih porsi sedang seharga Rp35.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_sedang = 35000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_sedang)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 3 :
            print("Anda memilih porsi besar seharga Rp40.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_besar = 40000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_besar)
            print("Silahkan bayar di kasir")
        else :
            print("Anda salah memilih porsi") #baris 47
    elif pilih_menu == 2 :
        print("=====================")
        print("        Porsi        ")
        print("=====================")
        print("1. Kecil Rp45.000")
        print("2. Sedang Rp50.000")
        print("3. Besar Rp55.000")
        pilih_porsi = int(input("Pilih porsi yang diinginkan : "))
        print("\n")
        if pilih_porsi == 1 :
            print("Anda memilih porsi kecil seharga Rp45.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_kecil = 45000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_kecil)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 2 :
            print("Anda memilih porsi sedang seharga Rp50.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_sedang = 50000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_sedang)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 3 :
            print("Anda memilih porsi besar seharga Rp40.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_besar = 55000*jmlh_porsi
            print("Total harga pesanan anda ",harga_porsi_besar)
            print("Silahkan bayar di kasir")
        else :
            print("Anda salah memilih porsi")
    elif pilih_menu == 3 :
        print("=====================")
        print("        Porsi        ")
        print("=====================")
        print("1. Kecil Rp60.000")
        print("2. Sedang Rp65.000")
        print("3. Besar Rp70.000")
        pilih_porsi = int(input("Pilih porsi yang diinginkan : "))
        print("\n")
        if pilih_porsi == 1 :
            print("Anda memilih porsi kecil seharga Rp30.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_kecil = 60000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_kecil)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 2 :
            print("Anda memilih porsi sedang seharga Rp35.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_sedang = 65000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_sedang)
            print("Silahkan bayar di kasir") #baris 100
            print("\n")
        elif pilih_porsi == 3 :
            print("Anda memilih porsi besar seharga Rp40.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_besar = 70000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_besar)
            print("Silahkan bayar di kasir")
            print("\n")
        else :
            print("Anda salah memilih porsi")
    elif pilih_menu == 4 :
        print("=====================")
        print("        Porsi        ")
        print("=====================")
        print("1. Kecil Rp75.000")
        print("2. Sedang Rp80.000")
        print("3. Besar Rp85.000")
        pilih_porsi = int(input("Pilih porsi yang diinginkan : "))
        print("\n")
        if pilih_porsi == 1 :
            print("Anda memilih porsi kecil seharga Rp30.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_kecil = 75000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_kecil)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 2 :
            print("Anda memilih porsi sedang seharga Rp35.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_sedang = 80000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_sedang)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 3 :
            print("Anda memilih porsi besar seharga Rp40.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_besar = 85000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_besar)
            print("Silahkan bayar di kasir")
            print("\n")
        else :
            print("Anda salah memilih porsi")
    elif pilih_menu == 5 :
        print("=====================")
        print("        Porsi        ")
        print("=====================")
        print("1. Kecil Rp90.000")
        print("2. Sedang Rp95.000")
        print("3. Besar Rp1000.000")
        pilih_porsi = int(input("Pilih porsi yang diinginkan : "))
        print("\n")
        if pilih_porsi == 1 :
            print("Anda memilih porsi kecil seharga Rp30.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_kecil = 90000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_kecil)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 2 :
            print("Anda memilih porsi sedang seharga Rp35.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_sedang = 95000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_sedang)
            print("Silahkan bayar di kasir")
            print("\n")
        elif pilih_porsi == 3 :
            print("Anda memilih porsi besar seharga Rp40.000")
            jmlh_porsi = int(input("Berapa jumlah porsi yang ingin dibeli? "))
            harga_porsi_besar = 100000*jmlh_porsi
            print("Total harga pesanan anda Rp",harga_porsi_besar)
            print("Silahkan bayar di kasir")
            print("\n")
        else :
            print("Anda salah memilih porsi")
    else :
        print("Anda salah memilih menu")
    
    print("## Terima kasih telah berbelanja di Burgeria ##")
menu() #baris 179
# Out:
# ...
#          Selamat Datang
#       di Restoran Burgeria
# ...
# Silahkan isi data diri anda terlebih dahulu
# Masukkan nama pembeli : Zakiyyun
# Masukkan umur pembeli : 19
#
#
# Berikut ini menu restoran yang ada :
# 1. Kentang Goreng
# 2. Burger Vegetarian
# 3. Burger Mayo
# 4. Burger Keju
# 5. Burger Pedas
# Masukkan menu yang ingin dibeli :5
#
#
# ...
#         Porsi
# ...
# 1. Kecil Rp90.000
# 2. Sedang Rp95.000
# 3. Besar Rp1000.000
# Pilih porsi yang diinginkan : 1
#
#
# Anda memilih porsi kecil seharga Rp30.000
# Berapa jumlah porsi yang ingin dibeli? 5
# Total harga pesanan anda Rp 450000
# Silahkan bayar di kasir
#
#
# ## Terima kasih telah berbelanja di Burgeria ##
